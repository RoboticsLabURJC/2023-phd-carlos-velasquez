# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, Lambda, Cropping2D, BatchNormalization, Dropout, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import Sequence
# from tensorflow.keras.metrics import MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError, CosineSimilarity

from tensorflow.keras.callbacks import EarlyStopping
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from datetime import datetime
import pandas as pd
# from PIL import Image
import numpy as np
import matplotlib.pyplot as plt


import albumentations as A
import wandb
from wandb.integration.keras import WandbCallback

import os
from datetime import datetime
import cv2

import warnings

warnings.filterwarnings("ignore") 
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '0'
# Out:
# 2024-09-04 08:20:58.137859: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-04 08:20:58.221138: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-04 08:20:58.276345: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-04 08:20:58.285998: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-04 08:20:58.342787: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-04 08:20:58.936151: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Listar los dispositivos físicos GPU disponibles
physical_devices = tf.config.list_physical_devices('GPU')
print("Dispositivos físicos:", physical_devices)

if physical_devices:
    try:
        # Configurar TensorFlow para usar solo la primera GPU visible
        tf.config.set_visible_devices(physical_devices[0], 'GPU')

        # Permitir el crecimiento dinámico de la memoria de la GPU
        for gpu in physical_devices:
            tf.config.experimental.set_memory_growth(gpu, True)

        # Verificar los dispositivos lógicos disponibles
        logical_devices = tf.config.list_logical_devices('GPU')
        print("Dispositivos lógicos:", logical_devices)
    except RuntimeError as e:
        # Errores se lanzan si la memoria de GPU ya ha sido configurada
        print(e)
else:
    print("No se encontraron GPUs disponibles.")
# Out:
# Dispositivos físicos: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Dispositivos lógicos: [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1725456065.212365    4918 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1725456065.311962    4918 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1725456065.312077    4918 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1725456065.313738    4918 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1725456065.313833    4918 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1725456065.313893    4918 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1725456065.360598    4918 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1725456065.360762    4918 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1725456065.360855    4918 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-04 08:21:05.361058: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5999 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
import os
import numpy as np
import cv2
from tensorflow.keras.utils import Sequence
import albumentations as A

# Definición de las transformaciones de entrenamiento y validación
train_transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.ColorJitter(brightness=0.2, contrast=0.3, saturation=0.2, hue=0.1, p=0.4),
    A.RandomBrightnessContrast(p=0.4),
    A.RandomGamma(gamma_limit=(50, 250), p=0.4),
    A.HueSaturationValue(
        hue_shift_limit=20,
        sat_shift_limit=30,
        val_shift_limit=20,
        p=0.4
    ),
    A.FancyPCA(alpha=0.1, p=0.4),
    A.GaussianBlur(blur_limit=(1, 3), p=0.4),
])

val_transform = A.Compose([])

class DataGenerator(Sequence):
    def __init__(self, x_set, y_set, batch_size, transform=None):
        self.x = x_set
        self.y = y_set
        self.batch_size = batch_size
        self.transform = transform

    def __len__(self):
        return int(np.ceil(len(self.x) / float(self.batch_size)))

    def __getitem__(self, idx):
        batch_x = self.x[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.y[idx * self.batch_size:(idx + 1) * self.batch_size]

        if self.transform:
            augmented_images = []
            augmented_labels = []

            for img, label in zip(batch_x, batch_y):
                transformed = self.transform(image=img)
                img = transformed["image"]

                # Verifica el número de canales y convierte a 3 si es necesario
                if img.shape[-1] == 4:
                    img = cv2.cvtColor(img, cv2.COLOR_RGBA2BGR)

                # Verificar si se aplicó el volteo horizontal
                if "horizontal_flip" in transformed:
                    if transformed["horizontal_flip"]:
                        label[0] = -label[0]  # Asumimos que 'steer' es el primer elemento en la etiqueta

                augmented_images.append(img)
                augmented_labels.append(label)

            batch_x = np.array(augmented_images)
            batch_y = np.array(augmented_labels)

        return batch_x, batch_y

# def get_images_array(df, base_path):
#     required_columns = ['image_name', 'steer']
#     for column in required_columns:
#         if column not in df.columns:
#             raise ValueError(f"La columna '{column}' no se encuentra en el DataFrame.")

#     steering_values = df['steer'].to_numpy()
#     image_paths = df['image_name'].tolist()

#     if len(image_paths) != len(steering_values):
#         raise ValueError("El número de nombres de imágenes no coincide con el número de valores de dirección.")

#     imagenes = []
#     labels = []

#     for index, image_path in enumerate(image_paths):
#         full_image_path = os.path.join(base_path, image_path)
#         if not os.path.isfile(full_image_path):
#             raise FileNotFoundError(f"La imagen {full_image_path} no se encuentra.")

#         # imagen = cv2.imread(full_image_path, cv2.IMREAD_UNCHANGED)
#         imagen = cv2.imread(full_image_path, cv2.IMREAD_COLOR)
#         if imagen is None:
#             raise ValueError(f"Error al leer la imagen {full_image_path}.")

#         img_cropped_resized = cv2.resize(imagen[200:-1, :], (200, 66))
#         array_imagen = np.array(img_cropped_resized)
#         # array_imagen_yuv = cv2.cvtColor(array_imagen, cv2.COLOR_RGB2YUV)

#         imagenes.append(array_imagen)
#         labels.append(steering_values[index])

#     return np.array(imagenes), np.array(labels)

# %%
import cv2
import os
import numpy as np
from concurrent.futures import ThreadPoolExecutor, as_completed

def process_image(image_info):
    image_path, steer_value, base_path = image_info
    full_image_path = os.path.join(base_path, image_path)
    
    if not os.path.isfile(full_image_path):
        raise FileNotFoundError(f"La imagen {full_image_path} no se encuentra.")
    
    imagen = cv2.imread(full_image_path, cv2.IMREAD_COLOR)
    if imagen is None:
        raise ValueError(f"Error al leer la imagen {full_image_path}.")
    
    img_cropped_resized = cv2.resize(imagen[200:-1, :], (200, 66))
    array_imagen = np.array(img_cropped_resized)
    
    return array_imagen, steer_value

def get_images_array(df, base_path, max_workers=8):
    required_columns = ['image_name', 'steer']
    for column in required_columns:
        if (column) not in df.columns:
            raise ValueError(f"La columna '{column}' no se encuentra en el DataFrame.")

    steering_values = df['steer'].to_numpy()
    image_paths = df['image_name'].tolist()

    if len(image_paths) != len(steering_values):
        raise ValueError("El número de nombres de imágenes no coincide con el número de valores de dirección.")

    imagenes = []
    labels = []

    image_info_list = [(image_paths[i], steering_values[i], base_path) for i in range(len(image_paths))]

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_image = {executor.submit(process_image, info): info for info in image_info_list}
        for future in as_completed(future_to_image):
            try:
                imagen, label = future.result()
                imagenes.append(imagen)
                labels.append(label)
            except Exception as exc:
                print(f'Error al procesar la imagen: {exc}')

    return np.array(imagenes), np.array(labels)

# %%
# data_path = '/home/canveo/carla_ros2_ws/carla_data_1/carla_data.csv'
# images_name = pd.read_csv(data_path)['image_name'].tolist()

# # imagenes, steering_values = get_images_array(data_path, images_name, 'recto')
# base_path = '/home/canveo/carla_ros2_ws/dataset'

# imagenes, labels = load_all_datasets(base_path)

# print("Imágenes shape:", imagenes.shape)
# print("Valores de dirección shape:", labels.shape)

# %%
import pandas as pd

# Definir la ruta base del dataset
base_path = '/home/canveo/carla_ws/dataset'  # Cambia esto a la ruta real de tu dataset

# Crear una lista para almacenar los DataFrames individuales
dataframes = []

# Iterar sobre cada carpeta en el dataset
for i in range(1, 13):
    folder_name = f"carla_data_{i}"
    folder_path = os.path.join(base_path, folder_name)
    csv_path = os.path.join(folder_path, "data.csv")
    
    if os.path.exists(csv_path):
        # Leer el archivo CSV en un DataFrame
        df = pd.read_csv(csv_path)
        
        # Filtrar las columnas necesarias
        df = df[["image_name", "steer", "throttle", "brake"]]
        
        # Agregar la ruta completa a la columna "image_name"
        df["image_name"] = df["image_name"].apply(lambda x: f"{folder_name}/images/{x}")
        
        # Agregar el DataFrame a la lista
        dataframes.append(df)

# Concatenar todos los DataFrames en uno solo
final_df = pd.concat(dataframes, ignore_index=True)

# Mostrar los primeros registros del DataFrame final
print(final_df.head())

# Guardar el DataFrame final en un archivo CSV si es necesario
final_df.to_csv(os.path.join(base_path, "combined_data.csv"), index=False)
# Out:
#                                    image_name  steer  throttle  brake
# 0  carla_data_1/images/frame1724103205448.png    0.0       0.0    0.0
# 1  carla_data_1/images/frame1724103205496.png    0.0       0.0    1.0
# 2  carla_data_1/images/frame1724103205540.png    0.0       0.0    1.0
# 3  carla_data_1/images/frame1724103205565.png    0.0       0.0    1.0
# 4  carla_data_1/images/frame1724103205587.png    0.0       0.0    1.0

# %%
image = cv2.imread('/home/canveo/carla_ws/dataset/carla_data_1/images/frame1724103205448.png')
height, width, channels = image.shape
b, g, r = image[0, 0]
print(f"Anchura: {width}, Altura: {height}, Canales: {channels}")
print(f"Valores de los canales (BGR): {b}, {g}, {r}")
# Out:
# Anchura: 800, Altura: 600, Canales: 3
# Valores de los canales (BGR): 115, 110, 98

# %%
num_bins = 25
samples_per_bin = 30000
hist, bins = np.histogram(final_df['steer'], num_bins)

# %%
center = (bins[:-1]+ bins[1:]) * 0.5

plt.bar(center, hist, width=0.05)

plt.plot((np.min(final_df['steer']), np.max(final_df['steer'])), (samples_per_bin, samples_per_bin))

# %%
print("Número total de datos: ", len(final_df))
# Out:
# Número total de datos:  202384

# %%
remove_list = []
for j in range(num_bins):
  list_ = []
  for i in range(len(final_df['steer'])):
    if final_df['steer'][i] >= bins[j] and final_df['steer'][i] <= bins[j+1]:
      list_.append(i)
  list_ = shuffle(list_)
  list_ = list_[samples_per_bin:]
  remove_list.extend(list_)
print('La cantidad de datos eliminados es {}:'.format(len(remove_list)))
# Out:
# La cantidad de datos eliminados es 120123:

# %%
final_df.drop(final_df.index[remove_list], inplace=True)
print('Cantidad de datos retenidos es {}'.format(len(final_df)))
# Out:
# Cantidad de datos retenidos es 82261

# %%
hist, _ = np.histogram(final_df['steer'], (num_bins))

plt.bar(center, hist, width=0.05)

plt.plot((np.min(final_df['steer']), np.max(final_df['steer'])), (samples_per_bin, samples_per_bin))

# %%
ranges = [x for x in np.arange(-1.0, 1.01, 0.08)]   # 25 ranges
grouped_counts = final_df.groupby(pd.cut(final_df['steer'], ranges), observed=False).count()
grouped_counts
# Out:
#                 image_name  steer  throttle  brake
# steer
# (-1.0, -0.92]            0      0         0      0
# (-0.92, -0.84]           0      0         0      0
# (-0.84, -0.76]          64     64        64     64
# (-0.76, -0.68]          59     59        59     59
# (-0.68, -0.6]          116    116       116    116
# (-0.6, -0.52]          309    309       309    309
# (-0.52, -0.44]         592    592       592    592
# (-0.44, -0.36]        1264   1264      1264   1264
# (-0.36, -0.28]        2108   2108      2108   2108
# (-0.28, -0.2]         3249   3249      3249   3249
# (-0.2, -0.12]         5567   5567      5567   5567
# (-0.12, -0.04]        9807   9807      9807   9807
# (-0.04, 0.04]        32418  32418     32418  32418
# (0.04, 0.12]         13636  13636     13636  13636
# (0.12, 0.2]           3650   3650      3650   3650
# (0.2, 0.28]           1597   1597      1597   1597
# (0.28, 0.36]          1453   1453      1453   1453
# (0.36, 0.44]          1457   1457      1457   1457
# (0.44, 0.52]           981    981       981    981
# (0.52, 0.6]            968    968       968    968
# (0.6, 0.68]           1006   1006      1006   1006
# (0.68, 0.76]           838    838       838    838
# (0.76, 0.84]          1122   1122      1122   1122
# (0.84, 0.92]             0      0         0      0
# (0.92, 1.0]              0      0         0      0

# %%
# Número deseado de muestras por intervalo
desired_count = 10000

# DataFrame para almacenar las muestras aumentadas
resampled = pd.DataFrame()
# 
# Iterar sobre los intervalos
for small_r in np.arange(-1, 1.01, 0.04):
    # Seleccionar el subconjunto de datos para el intervalo actual
    part_df = final_df.loc[(final_df['steer'] >= small_r) & (final_df['steer'] < small_r + 0.04)]
    
    # Verificar si el subconjunto de datos no está vacío
    if part_df.shape[0] > 0:
        # Calcular el número de veces que se debe repetir este intervalo
        repeat_factor = max(1, desired_count // part_df.shape[0])
        
        # Aumentar el número de muestras en el intervalo actual
        part_df_repeated = pd.concat([part_df] * repeat_factor, ignore_index=True)
        
        # Seleccionar aleatoriamente muestras adicionales si es necesario para alcanzar el número deseado
        remaining_samples = desired_count - part_df_repeated.shape[0]
        if remaining_samples > 0:
            part_df_remaining = part_df.sample(remaining_samples, replace=True, random_state=1)
            part_df_repeated = pd.concat([part_df_repeated, part_df_remaining], ignore_index=True)
        
        # Concatenar al DataFrame resampled
        resampled = pd.concat([resampled, part_df_repeated], ignore_index=True)

# %%
resampled
# Out:
#                                         image_name  steer  throttle  brake
# 0       carla_data_7/images/frame1724108525455.png   -0.8  0.193225    0.0
# 1       carla_data_7/images/frame1724108525479.png   -0.8  0.193225    0.0
# 2       carla_data_7/images/frame1724108525504.png   -0.8  0.220553    0.0
# 3       carla_data_7/images/frame1724108525526.png   -0.8  0.220553    0.0
# 4       carla_data_7/images/frame1724108525551.png   -0.8  0.220553    0.0
# ...                                            ...    ...       ...    ...
# 433710  carla_data_2/images/frame1724104848316.png    0.8  0.249178    0.0
# 433711  carla_data_7/images/frame1724109199999.png    0.8  0.850000    0.0
# 433712  carla_data_3/images/frame1724105871180.png    0.8  0.253004    0.0
# 433713  carla_data_3/images/frame1724106151603.png    0.8  0.299607    0.0
# 433714  carla_data_2/images/frame1724104510803.png    0.8  0.240050    0.0
#
# [433715 rows x 4 columns]

# %%
hist, _ = np.histogram(resampled['steer'], (num_bins))

plt.bar(center, hist, width=0.05)

plt.plot((np.min(resampled['steer']), np.max(resampled['steer'])), (samples_per_bin, samples_per_bin))

# %%
len(resampled)
# Out:
# 433715

# %%
base_path = '/home/canveo/carla_ws/dataset' 
all_images, all_labels = get_images_array(resampled, base_path)

# %%
X_train, X_val, y_train, y_val = train_test_split(all_images, all_labels, test_size=0.25, random_state=42)

# %%
X_train.shape
# Out:
# (325286, 66, 200, 3)

# %%
train_dataset = DataGenerator(X_train, y_train, batch_size=64, transform=train_transform)
val_dataset = DataGenerator(X_val, y_val, batch_size=64, transform=val_transform)

# %%
# import wandb
# # from wandb.keras import WandbCallback
# from wandb.integration.keras import WandbCallback

# # Inicializar wandb
# wandb.init(project="pilotnet-hyperparameter-tuning")

# # Configurar los hiperparámetros que se van a optimizar
# config = wandb.config
# config.learning_rate = 0.001  # Tasa de aprendizaje inicial
# config.epochs = 350           # Número de épocas inicial
# # config.batch_size = 32    
# # 
# # Definir el sweep
# # sweep_configuration = {
# #     'method': 'random',
# #     'metric': {'name': 'loss', 'goal': 'minimize'},
# #     'parameters': 
# #     {
# #         'learning_rate': {'values': [0.001, 0.0001, 0.00001]},
# #         'epochs': {'values': [50, 100, 200]},
# #         'batch_size': {'values': [32, 64, 128]}
# #     }
# # }

# %%
# Definir la arquitectura de PilotNet
img_shape = (66, 200, 3)
learning_rate = 0.0001    # 0.001, 0.0001
# learning_rate = wandb.config.learning_rate
model = Sequential()
model.add(BatchNormalization(epsilon=0.001, axis=-1, input_shape=img_shape))

# Capas convolucionales
model.add(Conv2D(24, (5, 5), strides=(2, 2), activation='relu'))
model.add(Conv2D(36, (5, 5), strides=(2, 2), activation='relu'))
model.add(Conv2D(48, (5, 5), strides=(2, 2), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))

model.add(Flatten())
model.add(Dense(1164, activation="relu"))
model.add(Dropout(0.1))
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(10, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(1))
# adam = Adam(learning_rate=config.learning_rate)
adam = Adam(learning_rate=learning_rate)

# Compilar el modelo
model.compile(
    optimizer=adam, 
    loss='mse',
    metrics=['mse', 'mae']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ batch_normalization             │ (None, 66, 200, 3)     │            12 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 31, 98, 24)     │         1,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 14, 47, 36)     │        21,636 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 5, 22, 48)      │        43,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 3, 20, 64)      │        27,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 1, 18, 64)      │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1164)           │     1,342,092 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1164)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 100)            │       116,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 50)             │         5,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │           510 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,595,523 (6.09 MB)
#  Trainable params: 1,595,517 (6.09 MB)
#  Non-trainable params: 6 (24.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Configura el EarlyStopping
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# wandb_cb = WandbCallback()

# %%
import json
import os

class TrainingLogger(tf.keras.callbacks.Callback):
    def __init__(self, log_dir, params):
        super(TrainingLogger, self).__init__()
        self.log_dir = log_dir
        self.params = params

    def on_train_begin(self, logs=None):
        with open(os.path.join(self.log_dir, 'training_params.json'), 'w') as f:
            json.dump(self.params, f)

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        with open(os.path.join(self.log_dir, f'epoch_{epoch}_logs.json'), 'w') as f:
            json.dump(logs, f)

# %%
import datetime
import tensorflow as tf
from tensorflow.keras.callbacks import TensorBoard

base_log_dir = "./logs"

# Crear un subdirectorio único para cada experimento
experiment_name = f"experiment_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
experiment_dir = os.path.join(base_log_dir, experiment_name)

# Asegurarse de que el subdirectorio del experimento existe
os.makedirs(experiment_dir, exist_ok=True)

batch_size = 64
learning_rate = 0.0001
dropout = 0.1

training_params = {
    "batch_size": batch_size,
    "learning_rate": learning_rate,
    "dropout": dropout,
    "epochs": 200,
}

training_logger_callback = TrainingLogger(experiment_dir, training_params)

# Guardar el archivo JSON dentro del subdirectorio del experimento
with open(os.path.join(experiment_dir, 'params.json'), 'w') as f:
    json.dump(training_params, f)

# (Opcional) Configurar TensorBoard para que también use este subdirectorio
tensorboard_callback = TensorBoard(log_dir=experiment_dir, histogram_freq=1)

# %%
# history = model.fit(
#     train_dataset,
#     validation_data=val_dataset,
#     # epochs=config.epochs,
#     epochs=400,
#     # batch_size=config.batch_size,
#     # batch_size=32,
#     # callbacks=[WandbCallback()]
#     callbacks=[es]
# )

# Crea el callback de TensorBoard
tensorboard_callback = TensorBoard(log_dir=experiment_dir, histogram_freq=1)


history = model.fit(train_dataset,
          epochs=training_params["epochs"],
          # batch_size=batch_size,
          validation_data=val_dataset,
          callbacks=[tensorboard_callback, early_stopping_callback, training_logger_callback])
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1725456794.481798    5028 service.cc:146] XLA service 0x724d44015a90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1725456794.481820    5028 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2024-09-04 08:33:14.528224: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-09-04 08:33:14.743941: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
#    6/5083 ━━━━━━━━━━━━━━━━━━━━ 2:15 27ms/step - loss: 0.2090 - mae: 0.3890 - mse: 0.2090
# I0000 00:00:1725456798.388617    5028 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 5082/5083 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0808 - mae: 0.2102 - mse: 0.0808
# 2024-09-04 08:36:10.157237: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_103', 240 bytes spill stores, 240 bytes spill loads
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 182s 35ms/step - loss: 0.0808 - mae: 0.2101 - mse: 0.0808 - val_loss: 0.0057 - val_mae: 0.0541 - val_mse: 0.0057
# Epoch 2/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 179s 35ms/step - loss: 0.0154 - mae: 0.0906 - mse: 0.0154 - val_loss: 0.0035 - val_mae: 0.0427 - val_mse: 0.0035
# Epoch 3/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 184s 36ms/step - loss: 0.0104 - mae: 0.0747 - mse: 0.0104 - val_loss: 0.0023 - val_mae: 0.0357 - val_mse: 0.0023
# Epoch 4/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 183s 36ms/step - loss: 0.0092 - mae: 0.0698 - mse: 0.0092 - val_loss: 0.0022 - val_mae: 0.0349 - val_mse: 0.0022
# Epoch 5/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 172s 34ms/step - loss: 0.0086 - mae: 0.0674 - mse: 0.0086 - val_loss: 0.0016 - val_mae: 0.0292 - val_mse: 0.0016
# Epoch 6/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 166s 33ms/step - loss: 0.0082 - mae: 0.0657 - mse: 0.0082 - val_loss: 0.0018 - val_mae: 0.0324 - val_mse: 0.0018
# Epoch 7/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 165s 32ms/step - loss: 0.0079 - mae: 0.0644 - mse: 0.0079 - val_loss: 0.0013 - val_mae: 0.0271 - val_mse: 0.0013
# Epoch 8/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 164s 32ms/step - loss: 0.0077 - mae: 0.0637 - mse: 0.0077 - val_loss: 0.0015 - val_mae: 0.0301 - val_mse: 0.0015
# Epoch 9/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 165s 32ms/step - loss: 0.0075 - mae: 0.0629 - mse: 0.0075 - val_loss: 0.0012 - val_mae: 0.0262 - val_mse: 0.0012
# Epoch 10/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 165s 32ms/step - loss: 0.0075 - mae: 0.0625 - mse: 0.0075 - val_loss: 0.0011 - val_mae: 0.0246 - val_mse: 0.0011
# Epoch 11/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 165s 32ms/step - loss: 0.0076 - mae: 0.0627 - mse: 0.0076 - val_loss: 0.0011 - val_mae: 0.0258 - val_mse: 0.0011
# Epoch 12/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 165s 32ms/step - loss: 0.0075 - mae: 0.0624 - mse: 0.0075 - val_loss: 0.0010 - val_mae: 0.0233 - val_mse: 0.0010
# Epoch 13/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 167s 33ms/step - loss: 0.0073 - mae: 0.0614 - mse: 0.0073 - val_loss: 0.0010 - val_mae: 0.0240 - val_mse: 0.0010
# Epoch 14/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 166s 33ms/step - loss: 0.0072 - mae: 0.0612 - mse: 0.0072 - val_loss: 9.9946e-04 - val_mae: 0.0244 - val_mse: 9.9946e-04
# Epoch 15/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 165s 32ms/step - loss: 0.0070 - mae: 0.0606 - mse: 0.0070 - val_loss: 0.0011 - val_mae: 0.0250 - val_mse: 0.0011
# Epoch 16/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 166s 33ms/step - loss: 0.0071 - mae: 0.0606 - mse: 0.0071 - val_loss: 0.0011 - val_mae: 0.0247 - val_mse: 0.0011
# Epoch 17/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 166s 33ms/step - loss: 0.0071 - mae: 0.0606 - mse: 0.0071 - val_loss: 9.8662e-04 - val_mae: 0.0233 - val_mse: 9.8662e-04
# Epoch 18/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 166s 33ms/step - loss: 0.0069 - mae: 0.0602 - mse: 0.0069 - val_loss: 9.0922e-04 - val_mae: 0.0224 - val_mse: 9.0922e-04
# Epoch 19/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 165s 32ms/step - loss: 0.0069 - mae: 0.0599 - mse: 0.0069 - val_loss: 0.0011 - val_mae: 0.0255 - val_mse: 0.0011
# Epoch 20/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 167s 33ms/step - loss: 0.0069 - mae: 0.0599 - mse: 0.0069 - val_loss: 8.5570e-04 - val_mae: 0.0219 - val_mse: 8.5570e-04
# Epoch 21/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 166s 33ms/step - loss: 0.0068 - mae: 0.0595 - mse: 0.0068 - val_loss: 0.0010 - val_mae: 0.0250 - val_mse: 0.0010
# Epoch 22/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 167s 33ms/step - loss: 0.0069 - mae: 0.0600 - mse: 0.0069 - val_loss: 0.0010 - val_mae: 0.0243 - val_mse: 0.0010
# Epoch 23/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 167s 33ms/step - loss: 0.0068 - mae: 0.0594 - mse: 0.0068 - val_loss: 8.7275e-04 - val_mae: 0.0228 - val_mse: 8.7275e-04
# Epoch 24/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 166s 33ms/step - loss: 0.0069 - mae: 0.0598 - mse: 0.0069 - val_loss: 8.1992e-04 - val_mae: 0.0216 - val_mse: 8.1992e-04
# Epoch 25/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 166s 33ms/step - loss: 0.0067 - mae: 0.0590 - mse: 0.0067 - val_loss: 8.5956e-04 - val_mae: 0.0227 - val_mse: 8.5956e-04
# Epoch 26/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 165s 33ms/step - loss: 0.0068 - mae: 0.0592 - mse: 0.0068 - val_loss: 9.6861e-04 - val_mae: 0.0237 - val_mse: 9.6861e-04
# Epoch 27/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 167s 33ms/step - loss: 0.0069 - mae: 0.0593 - mse: 0.0069 - val_loss: 8.8980e-04 - val_mae: 0.0216 - val_mse: 8.8980e-04
# Epoch 28/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 166s 33ms/step - loss: 0.0067 - mae: 0.0591 - mse: 0.0067 - val_loss: 9.3823e-04 - val_mae: 0.0233 - val_mse: 9.3823e-04
# Epoch 29/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 166s 33ms/step - loss: 0.0067 - mae: 0.0591 - mse: 0.0067 - val_loss: 7.5973e-04 - val_mae: 0.0211 - val_mse: 7.5973e-04
# Epoch 30/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 166s 33ms/step - loss: 0.0066 - mae: 0.0586 - mse: 0.0066 - val_loss: 7.3393e-04 - val_mae: 0.0201 - val_mse: 7.3393e-04
# Epoch 31/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 167s 33ms/step - loss: 0.0067 - mae: 0.0588 - mse: 0.0067 - val_loss: 9.3880e-04 - val_mae: 0.0235 - val_mse: 9.3880e-04
# Epoch 32/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 167s 33ms/step - loss: 0.0066 - mae: 0.0585 - mse: 0.0066 - val_loss: 7.1775e-04 - val_mae: 0.0202 - val_mse: 7.1775e-04
# Epoch 33/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 168s 33ms/step - loss: 0.0066 - mae: 0.0583 - mse: 0.0066 - val_loss: 8.0079e-04 - val_mae: 0.0223 - val_mse: 8.0079e-04
# Epoch 34/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 167s 33ms/step - loss: 0.0067 - mae: 0.0586 - mse: 0.0067 - val_loss: 7.9214e-04 - val_mae: 0.0221 - val_mse: 7.9214e-04
# Epoch 35/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 167s 33ms/step - loss: 0.0066 - mae: 0.0585 - mse: 0.0066 - val_loss: 7.4208e-04 - val_mae: 0.0210 - val_mse: 7.4208e-04
# Epoch 36/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 167s 33ms/step - loss: 0.0065 - mae: 0.0580 - mse: 0.0065 - val_loss: 8.0665e-04 - val_mae: 0.0221 - val_mse: 8.0665e-04
# Epoch 37/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 167s 33ms/step - loss: 0.0066 - mae: 0.0585 - mse: 0.0066 - val_loss: 6.8781e-04 - val_mae: 0.0194 - val_mse: 6.8781e-04
# Epoch 38/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 167s 33ms/step - loss: 0.0066 - mae: 0.0582 - mse: 0.0066 - val_loss: 8.1607e-04 - val_mae: 0.0218 - val_mse: 8.1607e-04
# Epoch 39/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 169s 33ms/step - loss: 0.0065 - mae: 0.0580 - mse: 0.0065 - val_loss: 7.5307e-04 - val_mae: 0.0201 - val_mse: 7.5307e-04
# Epoch 40/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 169s 33ms/step - loss: 0.0065 - mae: 0.0580 - mse: 0.0065 - val_loss: 7.7384e-04 - val_mae: 0.0212 - val_mse: 7.7384e-04
# Epoch 41/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 168s 33ms/step - loss: 0.0065 - mae: 0.0581 - mse: 0.0065 - val_loss: 6.3910e-04 - val_mae: 0.0190 - val_mse: 6.3910e-04
# Epoch 42/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 168s 33ms/step - loss: 0.0064 - mae: 0.0576 - mse: 0.0064 - val_loss: 5.9941e-04 - val_mae: 0.0186 - val_mse: 5.9941e-04
# Epoch 43/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 168s 33ms/step - loss: 0.0065 - mae: 0.0579 - mse: 0.0065 - val_loss: 5.8449e-04 - val_mae: 0.0174 - val_mse: 5.8449e-04
# Epoch 44/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 168s 33ms/step - loss: 0.0065 - mae: 0.0577 - mse: 0.0065 - val_loss: 5.8303e-04 - val_mae: 0.0180 - val_mse: 5.8303e-04
# Epoch 45/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 167s 33ms/step - loss: 0.0065 - mae: 0.0578 - mse: 0.0065 - val_loss: 9.5792e-04 - val_mae: 0.0243 - val_mse: 9.5792e-04
# Epoch 46/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 168s 33ms/step - loss: 0.0064 - mae: 0.0576 - mse: 0.0064 - val_loss: 6.8068e-04 - val_mae: 0.0198 - val_mse: 6.8068e-04
# Epoch 47/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 170s 33ms/step - loss: 0.0064 - mae: 0.0577 - mse: 0.0064 - val_loss: 7.1075e-04 - val_mae: 0.0204 - val_mse: 7.1075e-04
# Epoch 48/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 169s 33ms/step - loss: 0.0065 - mae: 0.0577 - mse: 0.0065 - val_loss: 6.0487e-04 - val_mae: 0.0188 - val_mse: 6.0487e-04
# Epoch 49/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 169s 33ms/step - loss: 0.0064 - mae: 0.0575 - mse: 0.0064 - val_loss: 6.3391e-04 - val_mae: 0.0194 - val_mse: 6.3391e-04
# Epoch 50/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 169s 33ms/step - loss: 0.0064 - mae: 0.0574 - mse: 0.0064 - val_loss: 6.7216e-04 - val_mae: 0.0199 - val_mse: 6.7216e-04
# Epoch 51/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 169s 33ms/step - loss: 0.0065 - mae: 0.0577 - mse: 0.0065 - val_loss: 7.4683e-04 - val_mae: 0.0197 - val_mse: 7.4683e-04
# Epoch 52/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 170s 33ms/step - loss: 0.0064 - mae: 0.0571 - mse: 0.0064 - val_loss: 5.3478e-04 - val_mae: 0.0170 - val_mse: 5.3478e-04
# Epoch 53/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 170s 33ms/step - loss: 0.0064 - mae: 0.0574 - mse: 0.0064 - val_loss: 6.4608e-04 - val_mae: 0.0195 - val_mse: 6.4608e-04
# Epoch 54/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 170s 33ms/step - loss: 0.0065 - mae: 0.0577 - mse: 0.0065 - val_loss: 5.6058e-04 - val_mae: 0.0178 - val_mse: 5.6058e-04
# Epoch 55/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 170s 33ms/step - loss: 0.0063 - mae: 0.0571 - mse: 0.0063 - val_loss: 5.5608e-04 - val_mae: 0.0172 - val_mse: 5.5608e-04
# Epoch 56/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 170s 33ms/step - loss: 0.0064 - mae: 0.0576 - mse: 0.0064 - val_loss: 6.4965e-04 - val_mae: 0.0197 - val_mse: 6.4965e-04
# Epoch 57/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 169s 33ms/step - loss: 0.0064 - mae: 0.0574 - mse: 0.0064 - val_loss: 6.1790e-04 - val_mae: 0.0186 - val_mse: 6.1790e-04
# Epoch 58/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 170s 33ms/step - loss: 0.0064 - mae: 0.0573 - mse: 0.0064 - val_loss: 6.4400e-04 - val_mae: 0.0198 - val_mse: 6.4400e-04
# Epoch 59/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 170s 33ms/step - loss: 0.0064 - mae: 0.0575 - mse: 0.0064 - val_loss: 6.1710e-04 - val_mae: 0.0190 - val_mse: 6.1710e-04
# Epoch 60/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 172s 34ms/step - loss: 0.0063 - mae: 0.0569 - mse: 0.0063 - val_loss: 6.7148e-04 - val_mae: 0.0202 - val_mse: 6.7148e-04
# Epoch 61/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 171s 34ms/step - loss: 0.0064 - mae: 0.0573 - mse: 0.0064 - val_loss: 6.1964e-04 - val_mae: 0.0188 - val_mse: 6.1964e-04
# Epoch 62/200
# 5083/5083 ━━━━━━━━━━━━━━━━━━━━ 171s 34ms/step - loss: 0.0064 - mae: 0.0569 - mse: 0.0064 - val_loss: 6.2159e-04 - val_mae: 0.0192 - val_mse: 6.2159e-04

# %%
# path_name = os.path.join('model/pilotnet_agos28_199ep.h5')
# model.save(path_name)
# model.save('model/pilonet_agost28_199ep.keras')
model.save(os.path.join(experiment_dir, 'trained_model.h5'))
model.save(os.path.join(experiment_dir, 'trained_model.keras'))
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'mae', 'mse', 'val_loss', 'val_mae', 'val_mse'])

# %%
# import matplotlib.pyplot as plt

# def plot_history(history):
#     plt.figure(figsize=(12, 8))
    
#     # Plot MSE (usando 'loss' en lugar de 'mse' ya que no hay 'mse' en las claves)
#     plt.subplot(2, 1, 1)
#     plt.plot(history.history['steering_angle_loss'], label='Train Steering MSE')
#     plt.plot(history.history['val_steering_angle_loss'], label='Val Steering MSE')
#     plt.plot(history.history['throttle_brake_loss'], label='Train Throttle MSE')
#     plt.plot(history.history['val_throttle_brake_loss'], label='Val Throttle MSE')
#     plt.title('Mean Squared Error (MSE)')
#     plt.ylabel('MSE')
#     plt.xlabel('Epoch')
#     plt.legend()
    
#     # Plot MAE
#     plt.subplot(2, 1, 2)
#     plt.plot(history.history['steering_angle_mae'], label='Train Steering MAE')
#     plt.plot(history.history['val_steering_angle_mae'], label='Val Steering MAE')
#     plt.plot(history.history['throttle_brake_mae'], label='Train Throttle MAE')
#     plt.plot(history.history['val_throttle_brake_mae'], label='Val Throttle MAE')
#     plt.title('Mean Absolute Error (MAE)')
#     plt.ylabel('MAE')
#     plt.xlabel('Epoch')
#     plt.legend()
    
#     plt.tight_layout()
#     plt.show()

# # Llama a la función para graficar
# plot_history(history)
import matplotlib.pyplot as plt


fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(10, 15))
ax1.plot(history.history['loss'], label='Training Loss')
ax1.plot(history.history['val_loss'], label='Validation Loss')
ax1.set_title('Training and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend()

# MAE plot
ax2.plot(history.history['mae'], label='Training MAE')
ax2.plot(history.history['val_mae'], label='Validation MAE')
ax2.set_title('Training and Validation MAE')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Mean Absolute Error')
ax2.legend()

# MSE plot
ax3.plot(history.history['mse'], label='Training MSE')
ax3.plot(history.history['val_mse'], label='Validation MSE')
ax3.set_title('Training and Validation MSE')
ax3.set_xlabel('Epochs')
ax3.set_ylabel('Mean Squared Error')
ax3.legend()

# Mostrar gráficos
plt.tight_layout()
plt.show()

# %%
import random
import matplotlib.pyplot as plt
from datetime import datetime
import os
import numpy as np

# Realizar la predicción
predictions = model.predict(X_val)

# Asumiendo que las predicciones son solo para steering
pred_steering = predictions

# Imprimir las formas para diagnóstico
print("Shape of pred_steering:", pred_steering.shape)
print("Shape of y_val:", y_val.shape)

# Seleccionar 4 índices aleatorios para la muestra
sample_indices = random.sample(range(len(X_val)), 4)

plt.figure(figsize=(15, 8))
for i, idx in enumerate(sample_indices, 1):
    plt.subplot(2, 2, i)
    
    # Mostrar la imagen
    plt.imshow(X_val[idx])
    
    # Mostrar las etiquetas reales y las predicciones
    real_steering = y_val[idx]
    pred_steering_val = pred_steering[idx]

    plt.title(
        f'Etiq. Real: Steer: {real_steering}\n'
        f'Predicción: Steer: {pred_steering_val}'
    )
    plt.axis('off')

plt.tight_layout()

# Crear el directorio de imágenes si no existe
os.makedirs('images', exist_ok=True)

# Guardar la imagen con la fecha y hora actual
# path_name = os.path.join('images/', str(datetime.now().strftime("%Y%m%d_%H%M%S")) + "_" + 'pilotnet' + '_prediccion' + '.png')
# plt.savefig(path_name)
plt.show()
# Out:
# 3389/3389 ━━━━━━━━━━━━━━━━━━━━ 3s 745us/step
# Shape of pred_steering: (108429, 1)
# Shape of y_val: (108429,)

# %%
import time
import numpy as np
import tensorflow as tf
from keras.models import load_model
from keras.saving import register_keras_serializable


@register_keras_serializable()
def mse(y_true, y_pred):
    return tf.reduce_mean(tf.square(y_true - y_pred))


# Cargar el modelo entrenado
# model = load_model('/home/canveo/Projects/notebook/model/modelos nuevos/nuevo_dp05_monolitico_epoch_202.h5', custom_objects={'mse': mse})

# Supongamos que tienes un lote de imágenes para la inferencia
batch_images = X_val[:32]  # Usando las primeras 32 imágenes del conjunto de vafflidación

# Medir el tiempo de inferencia
start_time = time.time()
predictions = model.predict(batch_images)
end_time = time.time()

# Calcular el tiempo de inferencia
inference_time = end_time - start_time
print(f"Tiempo de inferencia para un lote de 32 imágenes: {inference_time:.4f} segundos")

# Tiempo promedio por imagen
average_inference_time = inference_time / len(batch_images)
print(f"Tiempo promedio de inferencia por imagen: {average_inference_time:.6f} segundos")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Tiempo de inferencia para un lote de 32 imágenes: 0.0375 segundos
# Tiempo promedio de inferencia por imagen: 0.001173 segundos

# %%
import matplotlib.pyplot as plt
import os
from datetime import datetime

# Realizar la predicción
predictions = model.predict(X_val)

# Extraer las predicciones de ángulo de dirección
pred_steering = predictions

# Definir el rango de índices para la muestra
start_idx = 0
end_idx = 5000

plt.figure(figsize=(20, 6))

# Graficar etiquetas reales (ground truth) de ángulo de dirección
plt.plot(y_val[start_idx:end_idx], label='Real Steering')

# Graficar predicciones de ángulo de dirección
plt.plot(pred_steering[start_idx:end_idx], label='Predicted Steering')

plt.xlabel("Frames")
plt.ylabel("Steering Angle")
plt.legend()
plt.title("Comparación de Etiquetas Reales y Predicciones")

# Guardar la imagen
path_name = os.path.join('images/', str(datetime.now()) + "_" + 'pilotnet' + 'steering' + '.png')
plt.savefig(path_name)
plt.show()
# Out:
# 3389/3389 ━━━━━━━━━━━━━━━━━━━━ 2s 727us/step
